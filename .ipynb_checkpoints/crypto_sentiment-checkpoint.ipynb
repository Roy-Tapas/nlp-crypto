# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\tapas kumar
# [nltk_data]     roy\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")
api_key = 'fab7cad13cdb41d683bcfa18e1463c16'

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key = api_key)

# %%
# Fetch the Bitcoin news articles
btc_news = newsapi.get_everything(
    q="bitcoin", language="en"
)

# Print number occurences of the word 'bitcoin'
print(f"Total number occurences of the word Bitcoin: {btc_news['totalResults']}")

# Show sample article
btc_news["articles"][0]
# Out:
# Total umber occurences of the word Bitcoin: 8164
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Khari Johnson',
#  'title': 'Why Not Use Self-Driving Cars as Supercomputers?',
#  'description': 'Autonomous vehicles use the equivalent of 200 laptops to get around. Some want to tap that computing power to decode viruses or mine bitcoin.',
#  'url': 'https://www.wired.com/story/use-self-driving-cars-supercomputers/',
#  'urlToImage': 'https://media.wired.com/photos/60f081b4c147fe7a1a367362/191:100/w_1280,c_limit/Business-Autonomous-Vehicles-Supercomputers-1201885684.jpg',
#  'publishedAt': '2021-07-19T11:00:00Z',
#  'content': 'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]'}

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(
    q="ethereum", language="en"
)

# Print total articles
print(f"Total number occurences of the word Ethereum: {eth_news['totalResults']}")

# Show sample article
eth_news["articles"][0]
# Out:
# Total number occurences of the word Ethereum: 2366
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Connie Loizos',
#  'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’',
#  'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…',
#  'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667',
#  'publishedAt': '2021-07-16T16:00:55Z',
# ...

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []
btc_big_text = ''

for article in btc_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
        
        btc_big_text += text  # Saving for n-gram computation
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-19  Like Dogecoin devotees, the mayor of Reno, and...    0.6908
# 1  2021-07-05  Filed under:\r\nThe supply chain attack has re...   -0.5719
# 2  2021-07-05  image copyrightGetty Images\r\nThe gang behind...   -0.6124
# 3  2021-07-14  While retail investors grew more comfortable b...    0.7264
# 4  2021-07-21  As longtime TechCrunch readers know well, Mich...    0.2732
#
#    positive  negative  neutral
# 0     0.178     0.000    0.822
# 1     0.111     0.184    0.705
# 2     0.000     0.143    0.857
# 3     0.164     0.000    0.836
# 4     0.097     0.000    0.903

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []
eth_big_text =''

for article in eth_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
        })
        
        eth_big_text += text  # Saving for n-gram computation
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-16  There are many blockchain platforms competing ...    0.3612
# 1  2021-07-14  While retail investors grew more comfortable b...    0.7264
# 2  2021-07-02  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612
# 3  2021-07-17  "Anthony Di Iorio, a co-founder of the Ethereu...    0.6369
# 4  2021-07-05  Ether holders have "staked" more than $13 bill...    0.7717
#
#    positive  negative  neutral
# 0     0.075     0.000    0.925
# 1     0.164     0.000    0.836
# 2     0.110     0.041    0.849
# 3     0.157     0.000    0.843
# 4     0.194     0.000    0.806

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.018580   0.055650   0.048850   0.895450
# std     0.410904   0.066291   0.053598   0.075186
# min    -0.612400   0.000000   0.000000   0.705000
# 25%    -0.381800   0.000000   0.000000   0.840250
# 50%     0.000000   0.000000   0.057500   0.907500
# 75%     0.220025   0.108750   0.077750   0.927750
# max     0.726400   0.178000   0.184000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.235065   0.078650   0.024550   0.896800
# std     0.387401   0.068866   0.035195   0.065884
# min    -0.381800   0.000000   0.000000   0.782000
# 25%     0.000000   0.000000   0.000000   0.842750
# 50%     0.361200   0.077500   0.000000   0.920000
# 75%     0.528675   0.149250   0.067500   0.925000
# max     0.771700   0.194000   0.080000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z0-9]")  # regex to remove all non-alphanumeric chars by blank 
    re_clean = regex.sub(' ', text)  
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Remove stop words and Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    tokens = ' ' .join(tokens)
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc_tokens = []  

# Extract the text from the dataframe, pre-process and tokenize words
for index, row in btc_df.iterrows():
    try:
        preprocessed_words = tokenizer(row['text'])
        btc_tokens.append(preprocessed_words)
    except:
        pass


# Adding tokens as a col in the bitcoin dataframe
btc_df['tokens'] = btc_tokens
btc_df['tokens'][0]
# Out:
# 'like dogecoin devotee mayor reno leader el salvador aldo baoicchi convinced cryptocurrency future ceo founder canadian scooter maker daymak belief 4116 char'

# %%
# Create a new tokens column for Ethereum

eth_tokens = []  

# Extract the text from the dataframe, pre-process and tokenize words
for index, row in eth_df.iterrows():
    try:
        preprocessed_words = tokenizer(row['text'])
        eth_tokens.append(preprocessed_words)
    except:
        pass


# Adding tokens as a col in the bitcoin dataframe
eth_df['tokens'] = eth_tokens
eth_df['tokens'][0]
# Out:
# 'many blockchain platform competing investor developer attention right big daddy ethereum called ethereum killers like solana wrote 2563 char'

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_big_text = ''.join(btc_tokens)

# ngrams() function expects tokenized word. btc_big_text is a string object. withour word_tokenize() function ngrams() will sequence 
# individual chars
btc_words = word_tokenize(btc_big_text)
btc_bigram_counts = Counter(ngrams(btc_words, n=2))  
print(dict(btc_bigram_counts))
# Out:
# {('like', 'dogecoin'): 1, ('dogecoin', 'devotee'): 1, ('devotee', 'mayor'): 1, ('mayor', 'reno'): 1, ('reno', 'leader'): 1, ('leader', 'el'): 1, ('el', 'salvador'): 3, ('salvador', 'aldo'): 1, ('aldo', 'baoicchi'): 1, ('baoicchi', 'convinced'): 1, ('convinced', 'cryptocurrency'): 1, ('cryptocurrency', 'future'): 1, ('future', 'ceo'): 1, ('ceo', 'founder'): 1, ('founder', 'canadian'): 1, ('canadian', 'scooter'): 1, ('scooter', 'maker'): 1, ('maker', 'daymak'): 1, ('daymak', 'belief'): 1, ('belief', '4116'): 1, ('4116', 'charfiled'): 1, ('charfiled', 'supply'): 1, ('supply', 'chain'): 1, ('chain', 'attack'): 1, ('attack', 'ha'): 2, ('ha', 'reached'): 1, ('reached', 'thousand'): 1, ('thousand', 'organization'): 1, ('organization', 'illustration'): 1, ('illustration', 'alex'): 1, ('alex', 'castro'): 1, ('castro', 'verge'): 1, ('verge', 'three'): 1, ('three', 'day'): 1, ('day', 'ransomware'): 1, ('ransomware', 'attacker'): 1, ('attacker', 'started'): 1, ('started', 'holiday'): 1, ('holida
# ...

# %%
# Generate the Ethereum N-grams where N=2

eth_big_text = ''.join(eth_tokens)

# ngrams() function expects tokenized word. eth_big_text is a string object. withour word_tokenize() function ngrams() will sequence 
# individual chars
eth_words = word_tokenize(eth_big_text)
eth_bigram_counts = Counter(ngrams(eth_words, n=2))  
print(dict(eth_bigram_counts))
# Out:
# {('many', 'blockchain'): 1, ('blockchain', 'platform'): 1, ('platform', 'competing'): 1, ('competing', 'investor'): 1, ('investor', 'developer'): 1, ('developer', 'attention'): 1, ('attention', 'right'): 1, ('right', 'big'): 1, ('big', 'daddy'): 1, ('daddy', 'ethereum'): 1, ('ethereum', 'called'): 1, ('called', 'ethereum'): 1, ('ethereum', 'killers'): 1, ('killers', 'like'): 1, ('like', 'solana'): 1, ('solana', 'wrote'): 1, ('wrote', '2563'): 1, ('2563', 'charretail'): 1, ('charretail', 'investor'): 1, ('investor', 'grew'): 1, ('grew', 'comfortable'): 1, ('comfortable', 'buying'): 1, ('buying', 'cryptocurrencies'): 1, ('cryptocurrencies', 'like'): 1, ('like', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 2, ('ethereum', '2021'): 1, ('2021', 'decentralized'): 1, ('decentralized', 'application'): 1, ('application', 'world'): 1, ('world', 'still'): 1, ('still', 'ha'): 1, ('ha', 'lot'): 1, ('lot', 'work'): 1, ('work', 'come'): 1, ('come', 'onboarding'): 1, ('onboarding', '2288'): 1, ('2288', '
# ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_words, N=10)
# Out:
# [('bitcoin', 22),
#  ('reuters', 15),
#  ('june', 9),
#  ('cryptocurrency', 8),
#  ('illustration', 6),
#  ('2021', 5),
#  ('world', 5),
#  ('32', 5),
#  ('seen', 4),
#  ('taken', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_words, N=10)
# Out:
# [('bitcoin', 14),
#  ('ethereum', 11),
#  ('cryptocurrency', 11),
#  ('world', 7),
#  ('reuters', 7),
#  ('network', 6),
#  ('biggest', 5),
#  ('june', 5),
#  ('2', 4),
#  ('charreuters', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(btc_big_text)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(eth_big_text)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
article = btc_big_text

# %%
# Run the NER processor on all of the text
doc_btc = nlp(article)

# %%
# Render the visualization
displacy.render(doc_btc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Like Dogecoin devotees, the mayor of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and the leaders of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aldo Baoicchi
# ...

# %%
# List all Entities
print([ent.text for ent in doc_btc.ents if ent.label_ in ['GPE', 'NORP', 'ORG', 'MONEY', 'PERSON','LOC']])
# Out:
# ['Reno', 'El Salvador', 'Aldo Baoicchi', 'Canadian', 'Daymak', 'Alex Castro', 'The Verge', '$70m', '£50.5m', 'Bitcoin and Ethereum', 'Michael Arrington', 'TechCrunch', 'Crunchbase', 'Reuters', 'El Salvador', 'Reuters', 'El Salvador', 'Pr', 'REUTERS', 'Dado Ruvic/', 'Reuters', 'Reuters', 'China', 'Sichuan', 'as low as $32,288', 'REUTERS', 'Edgar Su/IllustrationJune 25', 'Reuters', '32,094.44', 'China', 'Reuters', '32,540.35', '3,049.42', 'Reuters', 'Reuters', '32,540.35', '3,049.42', 'Reuters', 'FILE', 'REUTERS', 'Edgar Su/Illustration/File Photo', 'Reuters', 'Martin/CNET\r\nA', 'UK', 'Spain', 'the US Department of Justi', 'Reuters', 'Reuters', '32,094.44', '2,554.88', 'REUTERS', 'Dado Ruvic', 'Reuters', '33', 'up to $15 million', "Sotheby's", 'Reuters', 'Reuters', '31,699.83', '2,937.27']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
article = eth_big_text

# %%
# Run the NER processor on all of the text
doc_eth = nlp(article)

# %%
# Render the visualization
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">many blockchain platform competing investor developer attention right big daddy ethereum called ethereum killers like solana wrote
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2563
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  charretail investor grew comfortable buying cryptocurrencies like bitcoin ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  decentralized application world still ha lot work come onboarding
# ...

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ in ['GPE', 'NORP', 'ORG', 'MONEY', 'PERSON','LOC']])
# Out:
# ['jpmorgan', 'american express', 'spanish', 'reuters', 'london', 'reuters', 'reuters', 'reuters', 'reuters']

# %% [markdown]
# ---
